# %% [markdown]
# # Web scraping
#
# All the prizemoney and numbers of winners are published on [The Lott](https://www.thelott.com/tattslotto/results).
#
# How can we scrape this to get all the data in a format that will make analysis possible?

# %% [markdown]
# Looking at the web page itself, we are looking for the the prize table. It includes the headings "Division", "Division Prize Pool" and "Winners"—these are the headings we are interested in for each date the lottery was drawn.

# %% [markdown]
# I found a reference to the `thelott.com` API on https://github.com/ShawInnes/coding-challenge and others. Pivoting to try POST requests to this API and understanding whether it continues to be available.

# %%
import requests

thelott_api = "https://data.api.thelott.com/sales/vmax/web/data/lotto/results/search/daterange/"

thelott_data = {
    "DateStart": "2020-12-31T13:00:00Z",
    "DateEnd": "2021-01-31T12:59:59Z",
    "ProductFilter": ["TattsLotto"],
    "CompanyFilter": ["Tattersalls"]
}

# %%
r = requests.post(url = thelott_api, json = thelott_data)

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{"Draws":[{"ProductId":"TattsLotto","DrawNumber":4125,"DrawDate":"2021-01-30T00:00:00","PrimaryNumbers":[20,3,31,30,15,6],"SecondaryNumbers":[2,26],"TicketNumbers":null,"Dividends":[{"Division":1,"BlocNumberOfWinners":4,"BlocDividend":1473168.7600,"CompanyId":"Tattersalls","CompanyNumberOfWinners":3,"CompanyDividend":1473168.7600,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":2,"BlocNumberOfWinners":79,"BlocDividend":8429.4500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":31,"CompanyDividend":8429.4500,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":3,"BlocNumberOfWinners":1442,"BlocDividend":698.9500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":547,"CompanyDividend":698.9500,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":4,"BlocNumberOfWinners":66790,"BlocDividend":22.3500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":25342,"CompanyDividend":22.3500,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":5,"BlocNumberOfWinners":161321,"BlocDividend":13.6500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":60539,"CompanyDividend":13.6500,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":6,"BlocNumberOfWinners":886413,"BlocDividend":7.6000,"CompanyId":"Tattersalls","CompanyNumberOfWinners":328760,"CompanyDividend":7.6000,"PoolTransferType":"NONE","PoolTransferredTo":0}]},{"ProductId":"TattsLotto","DrawNumber":4123,"DrawDate":"2021-01-23T00:00:00","PrimaryNumbers":[6,8,40,10,29,1],"SecondaryNumbers":[31,42],"TicketNumbers":null,"Dividends":[{"Division":1,"BlocNumberOfWinners":9,"BlocDividend":678308.1700,"CompanyId":"Tattersalls","CompanyNumberOfWinners":3,"CompanyDividend":678308.1700,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":2,"BlocNumberOfWinners":70,"BlocDividend":9878.9000,"CompanyId":"Tattersalls","CompanyNumberOfWinners":24,"CompanyDividend":9878.9000,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":3,"BlocNumberOfWinners":1493,"BlocDividend":701.0000,"CompanyId":"Tattersalls","CompanyNumberOfWinners":571,"CompanyDividend":701.0000,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":4,"BlocNumberOfWinners":74482,"BlocDividend":20.8500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":28349,"CompanyDividend":20.8500,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":5,"BlocNumberOfWinners":143997,"BlocDividend":15.9000,"CompanyId":"Tattersalls","CompanyNumberOfWinners":52046,"CompanyDividend":15.9000,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":6,"BlocNumberOfWinners":1007828,"BlocDividend":6.9500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":376665,"CompanyDividend":6.9500,"PoolTransferType":"NONE","PoolTransferredTo":0}]},{"ProductId":"TattsLotto","DrawNumber":4121,"DrawDate":"2021-01-16T00:00:00","PrimaryNumbers":[17,12,22,4,14,33],"SecondaryNumbers":[25,28],"TicketNumbers":null,"Dividends":[{"Division":1,"BlocNumberOfWinners":6,"BlocDividend":1052281.1200,"CompanyId":"Tattersalls","CompanyNumberOfWinners":2,"CompanyDividend":1052281.1200,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":2,"BlocNumberOfWinners":110,"BlocDividend":6475.0500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":41,"CompanyDividend":6475.0500,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":3,"BlocNumberOfWinners":1337,"BlocDividend":806.3000,"CompanyId":"Tattersalls","CompanyNumberOfWinners":483,"CompanyDividend":806.3000,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":4,"BlocNumberOfWinners":67533,"BlocDividend":23.6500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":23952,"CompanyDividend":23.6500,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":5,"BlocNumberOfWinners":173451,"BlocDividend":13.6000,"CompanyId":"Tattersalls","CompanyNumberOfWinners":63868,"CompanyDividend":13.6000,"PoolTransferType":"NONE","PoolTransferredTo":0},{"Division":6,"BlocNumberOfWinners":915938,"BlocDividend":7.8500,"CompanyId":"Tattersalls","CompanyNumberOfWinners":33 ...

# %%
r.headers
# Out:
# {'Pragma': 'no-cache', 'Content-Type': 'application/xml; charset=utf-8', 'Access-Control-Allow-Origin': '*', 'Content-Length': '247', 'Strict-Transport-Security': 'max-age=16070400; includeSubDomains', 'Cache-Control': 'no-cache, no-store', 'Expires': 'Sat, 27 Mar 2021 10:12:38 GMT', 'Date': 'Sat, 27 Mar 2021 10:12:38 GMT', 'Connection': 'close'}

# %%
r.request.body
# Out:
# 'DateStart=2020-12-31T13%3A00%3A00Z&DateEnd=2021-01-31T12%3A59%3A59Z&ProductFilter=TattsLotto&CompanyFilter=Tattersalls'

# %% [markdown]
# ## Loop over a series of years

# %% [markdown]
# ### 2020

# %%
import calendar
import json

# %%
years = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
months = [(month+1) for month in range(12)]
thelott_api = "https://data.api.thelott.com/sales/vmax/web/data/lotto/results/search/daterange/"
current_year = 2021
current_month = 3

# %%
results_list = []
productFilter = ["TattsLotto"]
companyFilter = ["Tattersalls"]
for year in years:
    for month in months:
        print(f'{year}{month:02}')
        _, last_day = calendar.monthrange(year, month)

        dateStart = f"{year}-{month:02}-01T01:00:00Z"
        dateEnd   = f"{year}-{month:02}-{last_day}T12:59:59Z"

        thelott_data = {
            "DateStart": dateStart,
            "DateEnd": dateEnd,
            "ProductFilter": productFilter,
            "CompanyFilter": companyFilter
        }
        r = requests.post(url = thelott_api, json = thelott_data)
        if r.ok:
            results_dict = json.loads(r.text)
            results_list.append(results_dict['Draws'])
        else:
            print('Error')
        if month == current_month and year == current_year:
            break
# Out:
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008
# 202009
# 202010
# 202011
# 202012
# 202101
# 202102
# 202103

# %%
results_list
# Out:
# [[{'ProductId': 'TattsLotto',
#    'DrawNumber': 3499,
#    'DrawDate': '2015-01-31T00:00:00',
#    'PrimaryNumbers': [36, 19, 26, 9, 15, 33],
#    'SecondaryNumbers': [4, 45],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 5,
#      'BlocDividend': 845849.21,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1,
#      'CompanyDividend': 845849.21,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 57,
#      'BlocDividend': 10061.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18,
#      'CompanyDividend': 10061.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1184,
#      'BlocDividend': 1045.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 457,
#      'CompanyDividend': 1045.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 58270,
#      'BlocDividend': 32.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 22243,
#      'CompanyDividend': 32.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 142924,
#      'BlocDividend': 21.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 54208,
#      'CompanyDividend': 21.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 268721,
#      'BlocDividend': 15.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 100592,
#      'CompanyDividend': 15.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3497,
#    'DrawDate': '2015-01-24T00:00:00',
#    'PrimaryNumbers': [34, 10, 30, 12, 44, 42],
#    'SecondaryNumbers': [1, 32],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 3,
#      'BlocDividend': 1423350.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 1423350.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 38,
#      'BlocDividend': 15271.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 13,
#      'CompanyDividend': 15271.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 997,
#      'BlocDividend': 1256.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 333,
#      'CompanyDividend': 1256.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 50931,
#      'BlocDividend': 37.2,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18137,
#      'CompanyDividend': 37.2,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 122525,
#      'BlocDividend': 25.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 43730,
#      'CompanyDividend': 25.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 244485,
#      'BlocDividend': 16.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 88968,
#      'CompanyDividend': 16.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3495,
#    'DrawDate': '2015-01-17T00:00:00',
#    'PrimaryNumbers': [30, 33, 16, 10, 1, 41],
#    'SecondaryNumbers': [28, 32],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 4,
#      'BlocDividend': 1047259.51,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1,
#      'CompanyDividend': 1047259.51,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 52,
#      'BlocDividend': 10948.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18,
#      'CompanyDividend': 10948.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1046,
#      'BlocDividend': 1174.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 393,
#      'CompanyDividend': 1174.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 49151,
#      'BlocDividend': 37.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18235,
#      'CompanyDividend': 37.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 124505,
#      'BlocDividend': 25.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 46664,
#      'CompanyDividend': 25.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 262632,
#      'BlocDividend': 15.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 98688,
#      'CompanyDividend': 15.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3493,
#    'DrawDate': '2015-01-10T00:00:00',
#    'PrimaryNumbers': [25, 4, 19, 27, 34, 24],
#    'SecondaryNumbers': [33, 41],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 4,
#      'BlocDividend': 1057519.12,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 1057519.12,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 50,
#      'BlocDividend': 11489.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 19,
#      'CompanyDividend': 11489.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1069,
#      'BlocDividend': 1159.6,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 431,
#      'CompanyDividend': 1159.6,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 57599,
#      'BlocDividend': 32.55,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 22137,
#      'CompanyDividend': 32.55,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 123235,
#      'BlocDividend': 25.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 44690,
#      'CompanyDividend': 25.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 260822,
#      'BlocDividend': 15.55,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 93190,
#      'CompanyDividend': 15.55,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3491,
#    'DrawDate': '2015-01-03T00:00:00',
#    'PrimaryNumbers': [39, 21, 18, 35, 38, 43],
#    'SecondaryNumbers': [13, 27],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 11,
#      'BlocDividend': 2727272.73,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 3,
#      'CompanyDividend': 2727272.73,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 230,
#      'BlocDividend': 9814.85,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 61,
#      'CompanyDividend': 9814.85,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 4196,
#      'BlocDividend': 1160.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1382,
#      'CompanyDividend': 1160.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 218426,
#      'BlocDividend': 33.7,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 68222,
#      'CompanyDividend': 33.7,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 556504,
#      'BlocDividend': 22.2,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 171047,
#      'CompanyDividend': 22.2,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 1281101,
#      'BlocDividend': 12.45,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 401849,
#      'CompanyDividend': 12.45,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}],
#  [{'ProductId': 'TattsLotto',
#    'DrawNumber': 3507,
#    'DrawDate': '2015-02-28T00:00:00',
#    'PrimaryNumbers': [11, 14, 45, 1, 33, 37],
#    'SecondaryNumbers': [41, 22],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 5,
#      'BlocDividend': 862236.02,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 862236.02,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 58,
#      'BlocDividend': 10085.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 22,
#      'CompanyDividend': 10085.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 950,
#      'BlocDividend': 1328.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 339,
#      'CompanyDividend': 1328.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 53124,
#      'BlocDividend': 35.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 19269,
#      'CompanyDividend': 35.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 140740,
#      'BlocDividend': 22.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 50819,
#      'CompanyDividend': 22.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 249872,
#      'BlocDividend': 16.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 89237,
#      'CompanyDividend': 16.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3505,
#    'DrawDate': '2015-02-21T00:00:00',
#    'PrimaryNumbers': [41, 24, 11, 10, 39, 5],
#    'SecondaryNumbers': [18, 3],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 2,
#      'BlocDividend': 2146470.27,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1,
#      'CompanyDividend': 2146470.27,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 36,
#      'BlocDividend': 16211.2,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 10,
#      'CompanyDividend': 16211.2,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 926,
#      'BlocDividend': 1360.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 301,
#      'CompanyDividend': 1360.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 51151,
#      'BlocDividend': 37.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18143,
#      'CompanyDividend': 37.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 137999,
#      'BlocDividend': 23.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 51398,
#      'CompanyDividend': 23.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 333766,
#      'BlocDividend': 12.35,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 129625,
#      'CompanyDividend': 12.35,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3503,
#    'DrawDate': '2015-02-14T00:00:00',
#    'PrimaryNumbers': [42, 22, 35, 16, 37, 24],
#    'SecondaryNumbers': [36, 29],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 9,
#      'BlocDividend': 2222222.23,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 2222222.23,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 166,
#      'BlocDividend': 10057.85,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 48,
#      'CompanyDividend': 10057.85,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 2898,
#      'BlocDividend': 1243.2,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 804,
#      'CompanyDividend': 1243.2,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 149505,
#      'BlocDividend': 36.45,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 47580,
#      'CompanyDividend': 36.45,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 378699,
#      'BlocDividend': 24.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 121302,
#      'CompanyDividend': 24.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 841740,
#      'BlocDividend': 14.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 270239,
#      'CompanyDividend': 14.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3501,
#    'DrawDate': '2015-02-07T00:00:00',
#    'PrimaryNumbers': [33, 30, 9, 19, 41, 44],
#    'SecondaryNumbers': [35, 36],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 7,
#      'BlocDividend': 608243.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 3,
#      'CompanyDividend': 608243.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 64,
#      'BlocDividend': 9025.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 20,
#      'CompanyDividend': 9025.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1097,
#      'BlocDividend': 1136.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 406,
#      'CompanyDividend': 1136.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 50884,
#      'BlocDividend': 37.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18257,
#      'CompanyDividend': 37.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 127891,
#      'BlocDividend': 24.7,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 46529,
#      'CompanyDividend': 24.7,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 246975,
#      'BlocDividend': 16.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 87892,
#      'CompanyDividend': 16.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}],
#  [{'ProductId': 'TattsLotto',
#    'DrawNumber': 3515,
#    'DrawDate': '2015-03-28T00:00:00',
#    'PrimaryNumbers': [29, 25, 13, 17, 16, 18],
#    'SecondaryNumbers': [26, 27],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 13,
#      'BlocDividend': 1615384.62,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 3,
#      'CompanyDividend': 1615384.62,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 190,
#      'BlocDividend': 7972.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 54,
#      'CompanyDividend': 7972.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 3023,
#      'BlocDividend': 1081.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 941,
#      'CompanyDividend': 1081.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 154902,
#      'BlocDividend': 31.9,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 50241,
#      'CompanyDividend': 31.9,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 399095,
#      'BlocDividend': 20.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 131853,
#      'CompanyDividend': 20.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 784105,
#      'BlocDividend': 13.6,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 251576,
#      'CompanyDividend': 13.6,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3513,
#    'DrawDate': '2015-03-21T00:00:00',
#    'PrimaryNumbers': [12, 39, 2, 11, 24, 16],
#    'SecondaryNumbers': [42, 43],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 9,
#      'BlocDividend': 473896.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 3,
#      'CompanyDividend': 473896.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 48,
#      'BlocDividend': 12066.85,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 12,
#      'CompanyDividend': 12066.85,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1080,
#      'BlocDividend': 1157.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 383,
#      'CompanyDividend': 1157.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 55947,
#      'BlocDividend': 33.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 20708,
#      'CompanyDividend': 33.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 121394,
#      'BlocDividend': 26.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 43422,
#      'CompanyDividend': 26.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 233645,
#      'BlocDividend': 17.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 82223,
#      'CompanyDividend': 17.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3511,
#    'DrawDate': '2015-03-14T00:00:00',
#    'PrimaryNumbers': [42, 9, 17, 43, 26, 7],
#    'SecondaryNumbers': [29, 24],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 3,
#      'BlocDividend': 1422427.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 1422427.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 44,
#      'BlocDividend': 13144.9,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 15,
#      'CompanyDividend': 13144.9,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1004,
#      'BlocDividend': 1243.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 383,
#      'CompanyDividend': 1243.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 55124,
#      'BlocDividend': 34.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 20094,
#      'CompanyDividend': 34.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 140595,
#      'BlocDividend': 22.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 51505,
#      'CompanyDividend': 22.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 292136,
#      'BlocDividend': 13.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 109824,
#      'CompanyDividend': 13.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3509,
#    'DrawDate': '2015-03-07T00:00:00',
#    'PrimaryNumbers': [40, 6, 3, 24, 41, 44],
#    'SecondaryNumbers': [25, 26],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 2,
#      'BlocDividend': 2146570.61,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 0,
#      'CompanyDividend': 2146570.61,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 53,
#      'BlocDividend': 10982.9,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 16,
#      'CompanyDividend': 10982.9,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 910,
#      'BlocDividend': 1380.35,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 304,
#      'CompanyDividend': 1380.35,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 46390,
#      'BlocDividend': 40.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 16510,
#      'CompanyDividend': 40.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 123719,
#      'BlocDividend': 25.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 45127,
#      'CompanyDividend': 25.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 273432,
#      'BlocDividend': 15.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 100684,
#      'CompanyDividend': 15.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}],
#  [{'ProductId': 'TattsLotto',
#    'DrawNumber': 3523,
#    'DrawDate': '2015-04-25T00:00:00',
#    'PrimaryNumbers': [20, 12, 7, 42, 29, 5],
#    'SecondaryNumbers': [30, 11],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 4,
#      'BlocDividend': 983996.06,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 983996.06,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 56,
#      'BlocDividend': 9534.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 17,
#      'CompanyDividend': 9534.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1252,
#      'BlocDividend': 920.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 519,
#      'CompanyDividend': 920.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 59800,
#      'BlocDividend': 29.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 24216,
#      'CompanyDividend': 29.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 160735,
#      'BlocDividend': 18.2,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 64009,
#      'CompanyDividend': 18.2,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 318689,
#      'BlocDividend': 11.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 126472,
#      'CompanyDividend': 11.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3521,
#    'DrawDate': '2015-04-18T00:00:00',
#    'PrimaryNumbers': [27, 14, 18, 16, 26, 4],
#    'SecondaryNumbers': [10, 5],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 4,
#      'BlocDividend': 1059075.2,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 3,
#      'CompanyDividend': 1059075.2,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 69,
#      'BlocDividend': 8323.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 29,
#      'CompanyDividend': 8323.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1212,
#      'BlocDividend': 1022.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 427,
#      'CompanyDividend': 1022.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 63727,
#      'BlocDividend': 29.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 24599,
#      'CompanyDividend': 29.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 165168,
#      'BlocDividend': 19.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 64143,
#      'CompanyDividend': 19.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 360989,
#      'BlocDividend': 11.2,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 140740,
#      'CompanyDividend': 11.2,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3519,
#    'DrawDate': '2015-04-11T00:00:00',
#    'PrimaryNumbers': [13, 21, 30, 3, 24, 7],
#    'SecondaryNumbers': [27, 4],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 13,
#      'BlocDividend': 316393.49,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 4,
#      'CompanyDividend': 316393.49,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 146,
#      'BlocDividend': 3820.9,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 63,
#      'CompanyDividend': 3820.9,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 2219,
#      'BlocDividend': 542.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 913,
#      'CompanyDividend': 542.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 85268,
#      'BlocDividend': 21.35,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 34302,
#      'CompanyDividend': 21.35,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 201386,
#      'BlocDividend': 15.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 79517,
#      'CompanyDividend': 15.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 352829,
#      'BlocDividend': 11.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 137234,
#      'CompanyDividend': 11.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3517,
#    'DrawDate': '2015-04-04T00:00:00',
#    'PrimaryNumbers': [40, 34, 1, 45, 44, 24],
#    'SecondaryNumbers': [20, 16],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 8,
#      'BlocDividend': 525190.66,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 525190.66,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 55,
#      'BlocDividend': 10353.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18,
#      'CompanyDividend': 10353.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 848,
#      'BlocDividend': 1449.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 289,
#      'CompanyDividend': 1449.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 50876,
#      'BlocDividend': 36.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18670,
#      'CompanyDividend': 36.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 132144,
#      'BlocDividend': 23.6,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 49406,
#      'CompanyDividend': 23.6,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 270022,
#      'BlocDividend': 14.85,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 102367,
#      'CompanyDividend': 14.85,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}],
#  [{'ProductId': 'TattsLotto',
#    'DrawNumber': 3533,
#    'DrawDate': '2015-05-30T00:00:00',
#    'PrimaryNumbers': [20, 16, 43, 36, 38, 23],
#    'SecondaryNumbers': [19, 13],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 3,
#      'BlocDividend': 1440094.64,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 1440094.64,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 51,
#      'BlocDividend': 11503.6,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 17,
#      'CompanyDividend': 11503.6,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 993,
#      'BlocDividend': 1274.9,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 354,
#      'CompanyDividend': 1274.9,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 50673,
#      'BlocDividend': 37.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18598,
#      'CompanyDividend': 37.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 138728,
#      'BlocDividend': 23.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 51523,
#      'CompanyDividend': 23.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 359921,
#      'BlocDividend': 11.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 140742,
#      'CompanyDividend': 11.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3531,
#    'DrawDate': '2015-05-23T00:00:00',
#    'PrimaryNumbers': [39, 31, 1, 2, 38, 45],
#    'SecondaryNumbers': [26, 34],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 4,
#      'BlocDividend': 1021747.62,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1,
#      'CompanyDividend': 1021747.62,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 42,
#      'BlocDividend': 13196.6,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 17,
#      'CompanyDividend': 13196.6,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 808,
#      'BlocDividend': 1480.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 264,
#      'CompanyDividend': 1480.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 41136,
#      'BlocDividend': 43.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 15207,
#      'CompanyDividend': 43.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 108223,
#      'BlocDividend': 28.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 39885,
#      'CompanyDividend': 28.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 237375,
#      'BlocDividend': 16.45,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 88514,
#      'CompanyDividend': 16.45,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3529,
#    'DrawDate': '2015-05-16T00:00:00',
#    'PrimaryNumbers': [10, 30, 26, 15, 45, 16],
#    'SecondaryNumbers': [21, 12],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 5,
#      'BlocDividend': 833829.87,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1,
#      'CompanyDividend': 833829.87,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 76,
#      'BlocDividend': 7454.9,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 38,
#      'CompanyDividend': 7454.9,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1118,
#      'BlocDividend': 1093.55,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 459,
#      'CompanyDividend': 1093.55,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 56139,
#      'BlocDividend': 32.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 21202,
#      'CompanyDividend': 32.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 145482,
#      'BlocDividend': 21.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 56125,
#      'CompanyDividend': 21.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 321521,
#      'BlocDividend': 12.45,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 124262,
#      'CompanyDividend': 12.45,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3527,
#    'DrawDate': '2015-05-09T00:00:00',
#    'PrimaryNumbers': [29, 31, 32, 27, 13, 4],
#    'SecondaryNumbers': [36, 34],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 17,
#      'BlocDividend': 1235294.12,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 5,
#      'CompanyDividend': 1235294.12,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 175,
#      'BlocDividend': 8911.45,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 58,
#      'CompanyDividend': 8911.45,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 3223,
#      'BlocDividend': 1044.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1019,
#      'CompanyDividend': 1044.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 164261,
#      'BlocDividend': 31.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 53054,
#      'CompanyDividend': 31.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 383639,
#      'BlocDividend': 22.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 124642,
#      'CompanyDividend': 22.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 750479,
#      'BlocDividend': 14.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 244050,
#      'CompanyDividend': 14.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3525,
#    'DrawDate': '2015-05-02T00:00:00',
#    'PrimaryNumbers': [15, 6, 18, 43, 35, 23],
#    'SecondaryNumbers': [44, 16],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 3,
#      'BlocDividend': 1388141.84,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 0,
#      'CompanyDividend': 1388141.84,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 45,
#      'BlocDividend': 12547.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 14,
#      'CompanyDividend': 12547.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1065,
#      'BlocDividend': 1144.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 393,
#      'CompanyDividend': 1144.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 53741,
#      'BlocDividend': 34.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 20153,
#      'CompanyDividend': 34.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 115880,
#      'BlocDividend': 26.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 42092,
#      'CompanyDividend': 26.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 230693,
#      'BlocDividend': 17.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 82451,
#      'CompanyDividend': 17.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}],
#  [{'ProductId': 'TattsLotto',
#    'DrawNumber': 3541,
#    'DrawDate': '2015-06-27T00:00:00',
#    'PrimaryNumbers': [39, 17, 30, 29, 15, 32],
#    'SecondaryNumbers': [21, 41],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 2,
#      'BlocDividend': 2171670.84,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 0,
#      'CompanyDividend': 2171670.84,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 43,
#      'BlocDividend': 13705.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 11,
#      'CompanyDividend': 13705.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 904,
#      'BlocDividend': 1406.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 318,
#      'CompanyDividend': 1406.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 49003,
#      'BlocDividend': 39.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 17794,
#      'CompanyDividend': 39.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 122948,
#      'BlocDividend': 26.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 44772,
#      'CompanyDividend': 26.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 255640,
#      'BlocDividend': 16.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 90312,
#      'CompanyDividend': 16.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3539,
#    'DrawDate': '2015-06-20T00:00:00',
#    'PrimaryNumbers': [44, 27, 22, 10, 8, 39],
#    'SecondaryNumbers': [25, 20],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 22,
#      'BlocDividend': 1000000.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 7,
#      'CompanyDividend': 1000000.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 198,
#      'BlocDividend': 7871.85,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 70,
#      'CompanyDividend': 7871.85,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 3490,
#      'BlocDividend': 963.7,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1078,
#      'CompanyDividend': 963.7,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 160550,
#      'BlocDividend': 31.7,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 50424,
#      'CompanyDividend': 31.7,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 382325,
#      'BlocDividend': 22.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 121529,
#      'CompanyDividend': 22.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 822935,
#      'BlocDividend': 13.35,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 268665,
#      'CompanyDividend': 13.35,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3537,
#    'DrawDate': '2015-06-13T00:00:00',
#    'PrimaryNumbers': [8, 38, 43, 36, 20, 45],
#    'SecondaryNumbers': [16, 29],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 3,
#      'BlocDividend': 1420218.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 0,
#      'CompanyDividend': 1420218.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 56,
#      'BlocDividend': 10331.85,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 26,
#      'CompanyDividend': 10331.85,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 894,
#      'BlocDividend': 1396.55,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 315,
#      'CompanyDividend': 1396.55,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 51928,
#      'BlocDividend': 36.35,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 19563,
#      'CompanyDividend': 36.35,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 147834,
#      'BlocDividend': 21.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 55947,
#      'CompanyDividend': 21.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 278969,
#      'BlocDividend': 14.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 102945,
#      'CompanyDividend': 14.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3535,
#    'DrawDate': '2015-06-06T00:00:00',
#    'PrimaryNumbers': [32, 31, 33, 29, 15, 39],
#    'SecondaryNumbers': [12, 22],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 6,
#      'BlocDividend': 722023.73,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 722023.73,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 40,
#      'BlocDividend': 14665.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 14,
#      'CompanyDividend': 14665.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 878,
#      'BlocDividend': 1441.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 319,
#      'CompanyDividend': 1441.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 50394,
#      'BlocDividend': 38.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18105,
#      'CompanyDividend': 38.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 127803,
#      'BlocDividend': 25.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 46832,
#      'CompanyDividend': 25.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 327763,
#      'BlocDividend': 12.6,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 125046,
#      'CompanyDividend': 12.6,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}],
#  [{'ProductId': 'TattsLotto',
#    'DrawNumber': 3549,
#    'DrawDate': '2015-07-25T00:00:00',
#    'PrimaryNumbers': [7, 20, 13, 8, 23, 32],
#    'SecondaryNumbers': [26, 34],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 3,
#      'BlocDividend': 1415048.16,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1,
#      'CompanyDividend': 1415048.16,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 93,
#      'BlocDividend': 6200.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 41,
#      'CompanyDividend': 6200.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1437,
#      'BlocDividend': 865.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 570,
#      'CompanyDividend': 865.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 72190,
#      'BlocDividend': 26.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 28927,
#      'CompanyDividend': 26.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 163967,
#      'BlocDividend': 19.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 64095,
#      'CompanyDividend': 19.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 261880,
#      'BlocDividend': 15.55,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 95894,
#      'CompanyDividend': 15.55,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3547,
#    'DrawDate': '2015-07-18T00:00:00',
#    'PrimaryNumbers': [3, 11, 29, 13, 38, 42],
#    'SecondaryNumbers': [19, 15],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 5,
#      'BlocDividend': 835719.07,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 835719.07,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 94,
#      'BlocDividend': 6030.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 31,
#      'CompanyDividend': 6030.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1351,
#      'BlocDividend': 905.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 502,
#      'CompanyDividend': 905.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 64486,
#      'BlocDividend': 28.7,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 23677,
#      'CompanyDividend': 28.7,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 164384,
#      'BlocDividend': 18.9,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 62286,
#      'CompanyDividend': 18.9,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 328486,
#      'BlocDividend': 12.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 127042,
#      'CompanyDividend': 12.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 3545,
#    'DrawDate': '2015-07-11T00:00:00',
#    'PrimaryNumbers': [28, 41, 14, 24, 45, 23],
#    'SecondaryNumbers': [5, 43],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 4,
#      'BlocDividend': 1050434.78,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 3,
#      'CompanyDividend': 1050434.78,
#      'PoolTransferType': 'NONE',
# ...
#      'BlocNumberOfWinners': 92072,
#      'BlocDividend': 25.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 30916,
#      'CompanyDividend': 25.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 242401,
#      'BlocDividend': 14.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 82523,
#      'CompanyDividend': 14.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 1303810,
#      'BlocDividend': 8.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 438317,
#      'CompanyDividend': 8.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 4117,
#    'DrawDate': '2021-01-02T00:00:00',
#    'PrimaryNumbers': [7, 5, 16, 44, 14, 17],
#    'SecondaryNumbers': [26, 31],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 19,
#      'BlocDividend': 1578947.37,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 7,
#      'CompanyDividend': 1578947.37,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 235,
#      'BlocDividend': 11461.35,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 63,
#      'CompanyDividend': 11461.35,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 4649,
#      'BlocDividend': 876.85,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1391,
#      'CompanyDividend': 876.85,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 241208,
#      'BlocDividend': 25.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 72864,
#      'CompanyDividend': 25.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 596146,
#      'BlocDividend': 14.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 184022,
#      'CompanyDividend': 14.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 3422957,
#      'BlocDividend': 7.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1041701,
#      'CompanyDividend': 7.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}],
#  [{'ProductId': 'TattsLotto',
#    'DrawNumber': 4133,
#    'DrawDate': '2021-02-27T00:00:00',
#    'PrimaryNumbers': [35, 24, 45, 4, 42, 6],
#    'SecondaryNumbers': [38, 36],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 1,
#      'BlocDividend': 5911619.2,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 0,
#      'CompanyDividend': 5911619.2,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 45,
#      'BlocDividend': 14840.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 18,
#      'CompanyDividend': 14840.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 820,
#      'BlocDividend': 1232.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 289,
#      'CompanyDividend': 1232.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 48851,
#      'BlocDividend': 30.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 17061,
#      'CompanyDividend': 30.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 123140,
#      'BlocDividend': 17.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 43800,
#      'CompanyDividend': 17.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 737895,
#      'BlocDividend': 9.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 263772,
#      'CompanyDividend': 9.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 4131,
#    'DrawDate': '2021-02-20T00:00:00',
#    'PrimaryNumbers': [9, 3, 5, 41, 35, 26],
#    'SecondaryNumbers': [45, 28],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 2,
#      'BlocDividend': 3062082.06,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 0,
#      'CompanyDividend': 3062082.06,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 59,
#      'BlocDividend': 11759.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 27,
#      'CompanyDividend': 11759.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1093,
#      'BlocDividend': 960.7,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 409,
#      'CompanyDividend': 960.7,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 59500,
#      'BlocDividend': 26.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 21132,
#      'CompanyDividend': 26.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 142701,
#      'BlocDividend': 16.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 50943,
#      'CompanyDividend': 16.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 873230,
#      'BlocDividend': 8.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 311871,
#      'CompanyDividend': 8.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 4129,
#    'DrawDate': '2021-02-13T00:00:00',
#    'PrimaryNumbers': [43, 22, 1, 4, 3, 42],
#    'SecondaryNumbers': [24, 25],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 8,
#      'BlocDividend': 2500000.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 2,
#      'CompanyDividend': 2500000.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 101,
#      'BlocDividend': 13772.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 28,
#      'CompanyDividend': 13772.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 2059,
#      'BlocDividend': 1022.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 614,
#      'CompanyDividend': 1022.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 109843,
#      'BlocDividend': 28.4,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 34351,
#      'CompanyDividend': 28.4,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 279356,
#      'BlocDividend': 16.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 89017,
#      'CompanyDividend': 16.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 1660993,
#      'BlocDividend': 8.45,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 544219,
#      'CompanyDividend': 8.45,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 4127,
#    'DrawDate': '2021-02-06T00:00:00',
#    'PrimaryNumbers': [3, 10, 12, 6, 8, 24],
#    'SecondaryNumbers': [36, 45],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 14,
#      'BlocDividend': 428018.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 6,
#      'CompanyDividend': 428018.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 80,
#      'BlocDividend': 8459.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 27,
#      'CompanyDividend': 8459.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 2515,
#      'BlocDividend': 407.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 945,
#      'CompanyDividend': 407.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 93938,
#      'BlocDividend': 16.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 35428,
#      'CompanyDividend': 16.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 154242,
#      'BlocDividend': 14.55,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 56384,
#      'CompanyDividend': 14.55,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 1059772,
#      'BlocDividend': 6.45,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 392906,
#      'CompanyDividend': 6.45,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}],
#  [{'ProductId': 'TattsLotto',
#    'DrawNumber': 4141,
#    'DrawDate': '2021-03-27T00:00:00',
#    'PrimaryNumbers': [35, 4, 2, 23, 12, 24],
#    'SecondaryNumbers': [37, 15],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 4,
#      'BlocDividend': 1487555.59,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 0,
#      'CompanyDividend': 1487555.59,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 49,
#      'BlocDividend': 13686.05,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 14,
#      'CompanyDividend': 13686.05,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1135,
#      'BlocDividend': 894.25,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 409,
#      'CompanyDividend': 894.25,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 61227,
#      'BlocDividend': 24.55,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 22307,
#      'CompanyDividend': 24.55,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 137893,
#      'BlocDividend': 16.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 49626,
#      'CompanyDividend': 16.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 873001,
#      'BlocDividend': 7.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 318352,
#      'CompanyDividend': 7.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 4139,
#    'DrawDate': '2021-03-20T00:00:00',
#    'PrimaryNumbers': [22, 32, 13, 8, 19, 9],
#    'SecondaryNumbers': [15, 25],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 8,
#      'BlocDividend': 2500000.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1,
#      'CompanyDividend': 2500000.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 140,
#      'BlocDividend': 9167.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 46,
#      'CompanyDividend': 9167.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 2387,
#      'BlocDividend': 813.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 799,
#      'CompanyDividend': 813.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 124407,
#      'BlocDividend': 23.15,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 41667,
#      'CompanyDividend': 23.15,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 304474,
#      'BlocDividend': 13.95,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 103548,
#      'CompanyDividend': 13.95,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 1731299,
#      'BlocDividend': 7.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 587577,
#      'CompanyDividend': 7.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 4137,
#    'DrawDate': '2021-03-13T00:00:00',
#    'PrimaryNumbers': [27, 17, 37, 15, 40, 22],
#    'SecondaryNumbers': [2, 4],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 5,
#      'BlocDividend': 1165537.35,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 1,
#      'CompanyDividend': 1165537.35,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 68,
#      'BlocDividend': 9707.5,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 24,
#      'CompanyDividend': 9707.5,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1087,
#      'BlocDividend': 919.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 377,
#      'CompanyDividend': 919.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 60015,
#      'BlocDividend': 24.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 22003,
#      'CompanyDividend': 24.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 148217,
#      'BlocDividend': 14.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 54132,
#      'CompanyDividend': 14.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 805827,
#      'BlocDividend': 8.3,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 291839,
#      'CompanyDividend': 8.3,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]},
#   {'ProductId': 'TattsLotto',
#    'DrawNumber': 4135,
#    'DrawDate': '2021-03-06T00:00:00',
#    'PrimaryNumbers': [42, 26, 32, 16, 39, 11],
#    'SecondaryNumbers': [30, 6],
#    'TicketNumbers': None,
#    'Dividends': [{'Division': 1,
#      'BlocNumberOfWinners': 5,
#      'BlocDividend': 1156990.8,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 4,
#      'CompanyDividend': 1156990.8,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 2,
#      'BlocNumberOfWinners': 82,
#      'BlocDividend': 7971.35,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 28,
#      'CompanyDividend': 7971.35,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 3,
#      'BlocNumberOfWinners': 1112,
#      'BlocDividend': 889.65,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 401,
#      'CompanyDividend': 889.65,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 4,
#      'BlocNumberOfWinners': 54150,
#      'BlocDividend': 27.1,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 19185,
#      'CompanyDividend': 27.1,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 5,
#      'BlocNumberOfWinners': 135261,
#      'BlocDividend': 16.0,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 47935,
#      'CompanyDividend': 16.0,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0},
#     {'Division': 6,
#      'BlocNumberOfWinners': 755056,
#      'BlocDividend': 8.75,
#      'CompanyId': 'Tattersalls',
#      'CompanyNumberOfWinners': 270343,
#      'CompanyDividend': 8.75,
#      'PoolTransferType': 'NONE',
#      'PoolTransferredTo': 0}]}]]

# %%
len(results_list)
# Out:
# 75

# %%
results_list[0]
# Out:
# [{'ProductId': 'TattsLotto',
#   'DrawNumber': 3499,
#   'DrawDate': '2015-01-31T00:00:00',
#   'PrimaryNumbers': [36, 19, 26, 9, 15, 33],
#   'SecondaryNumbers': [4, 45],
#   'TicketNumbers': None,
#   'Dividends': [{'Division': 1,
#     'BlocNumberOfWinners': 5,
#     'BlocDividend': 845849.21,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 1,
#     'CompanyDividend': 845849.21,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 2,
#     'BlocNumberOfWinners': 57,
#     'BlocDividend': 10061.5,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 18,
#     'CompanyDividend': 10061.5,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 3,
#     'BlocNumberOfWinners': 1184,
#     'BlocDividend': 1045.25,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 457,
#     'CompanyDividend': 1045.25,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 4,
#     'BlocNumberOfWinners': 58270,
#     'BlocDividend': 32.1,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 22243,
#     'CompanyDividend': 32.1,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 5,
#     'BlocNumberOfWinners': 142924,
#     'BlocDividend': 21.95,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 54208,
#     'CompanyDividend': 21.95,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 6,
#     'BlocNumberOfWinners': 268721,
#     'BlocDividend': 15.05,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 100592,
#     'CompanyDividend': 15.05,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0}]},
#  {'ProductId': 'TattsLotto',
#   'DrawNumber': 3497,
#   'DrawDate': '2015-01-24T00:00:00',
#   'PrimaryNumbers': [34, 10, 30, 12, 44, 42],
#   'SecondaryNumbers': [1, 32],
#   'TicketNumbers': None,
#   'Dividends': [{'Division': 1,
#     'BlocNumberOfWinners': 3,
#     'BlocDividend': 1423350.75,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 2,
#     'CompanyDividend': 1423350.75,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 2,
#     'BlocNumberOfWinners': 38,
#     'BlocDividend': 15271.95,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 13,
#     'CompanyDividend': 15271.95,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 3,
#     'BlocNumberOfWinners': 997,
#     'BlocDividend': 1256.05,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 333,
#     'CompanyDividend': 1256.05,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 4,
#     'BlocNumberOfWinners': 50931,
#     'BlocDividend': 37.2,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 18137,
#     'CompanyDividend': 37.2,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 5,
#     'BlocNumberOfWinners': 122525,
#     'BlocDividend': 25.95,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 43730,
#     'CompanyDividend': 25.95,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 6,
#     'BlocNumberOfWinners': 244485,
#     'BlocDividend': 16.75,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 88968,
#     'CompanyDividend': 16.75,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0}]},
#  {'ProductId': 'TattsLotto',
#   'DrawNumber': 3495,
#   'DrawDate': '2015-01-17T00:00:00',
#   'PrimaryNumbers': [30, 33, 16, 10, 1, 41],
#   'SecondaryNumbers': [28, 32],
#   'TicketNumbers': None,
#   'Dividends': [{'Division': 1,
#     'BlocNumberOfWinners': 4,
#     'BlocDividend': 1047259.51,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 1,
#     'CompanyDividend': 1047259.51,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 2,
#     'BlocNumberOfWinners': 52,
#     'BlocDividend': 10948.3,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 18,
#     'CompanyDividend': 10948.3,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 3,
#     'BlocNumberOfWinners': 1046,
#     'BlocDividend': 1174.5,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 393,
#     'CompanyDividend': 1174.5,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 4,
#     'BlocNumberOfWinners': 49151,
#     'BlocDividend': 37.8,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 18235,
#     'CompanyDividend': 37.8,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 5,
#     'BlocNumberOfWinners': 124505,
#     'BlocDividend': 25.05,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 46664,
#     'CompanyDividend': 25.05,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 6,
#     'BlocNumberOfWinners': 262632,
#     'BlocDividend': 15.3,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 98688,
#     'CompanyDividend': 15.3,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0}]},
#  {'ProductId': 'TattsLotto',
#   'DrawNumber': 3493,
#   'DrawDate': '2015-01-10T00:00:00',
#   'PrimaryNumbers': [25, 4, 19, 27, 34, 24],
#   'SecondaryNumbers': [33, 41],
#   'TicketNumbers': None,
#   'Dividends': [{'Division': 1,
#     'BlocNumberOfWinners': 4,
#     'BlocDividend': 1057519.12,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 2,
#     'CompanyDividend': 1057519.12,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 2,
#     'BlocNumberOfWinners': 50,
#     'BlocDividend': 11489.1,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 19,
#     'CompanyDividend': 11489.1,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 3,
#     'BlocNumberOfWinners': 1069,
#     'BlocDividend': 1159.6,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 431,
#     'CompanyDividend': 1159.6,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 4,
#     'BlocNumberOfWinners': 57599,
#     'BlocDividend': 32.55,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 22137,
#     'CompanyDividend': 32.55,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 5,
#     'BlocNumberOfWinners': 123235,
#     'BlocDividend': 25.5,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 44690,
#     'CompanyDividend': 25.5,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 6,
#     'BlocNumberOfWinners': 260822,
#     'BlocDividend': 15.55,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 93190,
#     'CompanyDividend': 15.55,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0}]},
#  {'ProductId': 'TattsLotto',
#   'DrawNumber': 3491,
#   'DrawDate': '2015-01-03T00:00:00',
#   'PrimaryNumbers': [39, 21, 18, 35, 38, 43],
#   'SecondaryNumbers': [13, 27],
#   'TicketNumbers': None,
#   'Dividends': [{'Division': 1,
#     'BlocNumberOfWinners': 11,
#     'BlocDividend': 2727272.73,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 3,
#     'CompanyDividend': 2727272.73,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 2,
#     'BlocNumberOfWinners': 230,
#     'BlocDividend': 9814.85,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 61,
#     'CompanyDividend': 9814.85,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 3,
#     'BlocNumberOfWinners': 4196,
#     'BlocDividend': 1160.95,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 1382,
#     'CompanyDividend': 1160.95,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 4,
#     'BlocNumberOfWinners': 218426,
#     'BlocDividend': 33.7,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 68222,
#     'CompanyDividend': 33.7,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 5,
#     'BlocNumberOfWinners': 556504,
#     'BlocDividend': 22.2,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 171047,
#     'CompanyDividend': 22.2,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0},
#    {'Division': 6,
#     'BlocNumberOfWinners': 1281101,
#     'BlocDividend': 12.45,
#     'CompanyId': 'Tattersalls',
#     'CompanyNumberOfWinners': 401849,
#     'CompanyDividend': 12.45,
#     'PoolTransferType': 'NONE',
#     'PoolTransferredTo': 0}]}]

# %%
len(results_list[0])
# Out:
# 5

# %%
this_list = results_list[0]
this_draw = this_list[0]
this_draw
# Out:
# {'ProductId': 'TattsLotto',
#  'DrawNumber': 3499,
#  'DrawDate': '2015-01-31T00:00:00',
#  'PrimaryNumbers': [36, 19, 26, 9, 15, 33],
#  'SecondaryNumbers': [4, 45],
#  'TicketNumbers': None,
#  'Dividends': [{'Division': 1,
#    'BlocNumberOfWinners': 5,
#    'BlocDividend': 845849.21,
#    'CompanyId': 'Tattersalls',
#    'CompanyNumberOfWinners': 1,
#    'CompanyDividend': 845849.21,
#    'PoolTransferType': 'NONE',
#    'PoolTransferredTo': 0},
#   {'Division': 2,
#    'BlocNumberOfWinners': 57,
#    'BlocDividend': 10061.5,
#    'CompanyId': 'Tattersalls',
#    'CompanyNumberOfWinners': 18,
#    'CompanyDividend': 10061.5,
#    'PoolTransferType': 'NONE',
#    'PoolTransferredTo': 0},
#   {'Division': 3,
#    'BlocNumberOfWinners': 1184,
#    'BlocDividend': 1045.25,
#    'CompanyId': 'Tattersalls',
#    'CompanyNumberOfWinners': 457,
#    'CompanyDividend': 1045.25,
#    'PoolTransferType': 'NONE',
#    'PoolTransferredTo': 0},
#   {'Division': 4,
#    'BlocNumberOfWinners': 58270,
#    'BlocDividend': 32.1,
#    'CompanyId': 'Tattersalls',
#    'CompanyNumberOfWinners': 22243,
#    'CompanyDividend': 32.1,
#    'PoolTransferType': 'NONE',
#    'PoolTransferredTo': 0},
#   {'Division': 5,
#    'BlocNumberOfWinners': 142924,
#    'BlocDividend': 21.95,
#    'CompanyId': 'Tattersalls',
#    'CompanyNumberOfWinners': 54208,
#    'CompanyDividend': 21.95,
#    'PoolTransferType': 'NONE',
#    'PoolTransferredTo': 0},
#   {'Division': 6,
#    'BlocNumberOfWinners': 268721,
#    'BlocDividend': 15.05,
#    'CompanyId': 'Tattersalls',
#    'CompanyNumberOfWinners': 100592,
#    'CompanyDividend': 15.05,
#    'PoolTransferType': 'NONE',
#    'PoolTransferredTo': 0}]}

# %% [markdown]
# Create the draw table.

# %%
import pandas as pd

draw_df_list = []
numbers_df_list = []
dividends_df_list = []
for result in results_list:
    for draw in result:
        draw_df_list.append(dict(DrawNumber=draw['DrawNumber'], DrawDate=pd.to_datetime(draw['DrawDate'])))
        number_list = []
        number_type = 'Primary'
        order = 0
        for number in draw['PrimaryNumbers']:
            order += 1
            number_list.append(dict(DrawNumber=draw['DrawNumber'], NumberDrawn=number, NumberType=number_type, Order=order))
        number_type = 'Secondary'
        order = 0
        for number in draw['SecondaryNumbers']:
            order += 1
            number_list.append(dict(DrawNumber=draw['DrawNumber'], NumberDrawn=number, NumberType=number_type, Order=order))
        numbers_df_list.append(pd.DataFrame(number_list))
        dividends_df = pd.DataFrame(draw['Dividends'])
        dividends_df['DrawNumber'] = draw['DrawNumber']
        dividends_df_list.append(dividends_df)

# %%
draws_df = pd.DataFrame(draw_df_list)
draws_df.head()
# Out:
#    DrawNumber   DrawDate
# 0        3499 2015-01-31
# 1        3497 2015-01-24
# 2        3495 2015-01-17
# 3        3493 2015-01-10
# 4        3491 2015-01-03

# %%
numbers_df = pd.concat(numbers_df_list)
numbers_df.head(9)
# Out:
#    DrawNumber  NumberDrawn NumberType  Order
# 0        3499           36    Primary      1
# 1        3499           19    Primary      2
# 2        3499           26    Primary      3
# 3        3499            9    Primary      4
# 4        3499           15    Primary      5
# 5        3499           33    Primary      6
# 6        3499            4  Secondary      1
# 7        3499           45  Secondary      2
# 0        3497           34    Primary      1

# %%
dividends_df = pd.concat(dividends_df_list)
dividends_df.head(10)
# Out:
#    Division  BlocNumberOfWinners  BlocDividend    CompanyId  \
# 0         1                    5     845849.21  Tattersalls
# 1         2                   57      10061.50  Tattersalls
# 2         3                 1184       1045.25  Tattersalls
# 3         4                58270         32.10  Tattersalls
# 4         5               142924         21.95  Tattersalls
# 5         6               268721         15.05  Tattersalls
# 0         1                    3    1423350.75  Tattersalls
# 1         2                   38      15271.95  Tattersalls
# 2         3                  997       1256.05  Tattersalls
# 3         4                50931         37.20  Tattersalls
#
#    CompanyNumberOfWinners  CompanyDividend PoolTransferType  \
# 0                       1        845849.21             NONE
# 1                      18         10061.50             NONE
# 2                     457          1045.25             NONE
# 3                   22243            32.10             NONE
# 4                   54208            21.95             NONE
# 5                  100592            15.05             NONE
# 0                       2       1423350.75             NONE
# 1                      13         15271.95             NONE
# 2                     333          1256.05             NONE
# 3                   18137            37.20             NONE
#
#    PoolTransferredTo  DrawNumber
# 0                  0        3499
# 1                  0        3499
# 2                  0        3499
# 3                  0        3499
# 4                  0        3499
# 5                  0        3499
# 0                  0        3497
# 1                  0        3497
# 2                  0        3497
# 3                  0        3497

# %% [markdown]
# ### Save the data

# %%
draws_filename = 'draws.pkl'
numbers_filename = 'numbers.pkl'
dividends_filename = 'dividends.pkl'

# %%
draws_df.to_pickle(draws_filename)
numbers_df.to_pickle(numbers_filename)
dividends_df.to_pickle(dividends_filename)
